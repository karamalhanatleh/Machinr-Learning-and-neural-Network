# %% [markdown]
# # Logistic Regression

# %%
#import
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.linear_model import LogisticRegression

# %%
x = np.array([92., 24., 34., 45., 46., 57., 64., 69., 49., 92.])
x = x.reshape(-1, 1)

y=np.array([1 ,0 ,0 ,0 ,0  ,1 ,1, 1, 0, 1])
plt.plot(x,y)

# %%
model=LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
model.predict([[92]])
# Out:
# array([1])

# %%
##################################

# %%
#import paskages
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
xs=np.array([92., 24., 34., 45., 46., 57., 64., 69., 49., 92.])
ys=np.array([1 ,0 ,0 ,0 ,0  ,1 ,1, 1, 0, 1] )

# %%
model=keras.models.Sequential([
    keras.layers.Dense(units=1 , input_shape=[1]),
    keras.layers.Dense(1,activation='sigmoid' )
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(xs,ys , epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 328ms/step - loss: 4.0512 - accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0179 - accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3.9847 - accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9514 - accuracy: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 0s 5ms/step - loss: 3.9183 - accuracy: 0.5000
# Epoch 6/10
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8851 - accuracy: 0.5000
# Epoch 7/10
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8521 - accuracy: 0.5000
# Epoch 8/10
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8190 - accuracy: 0.5000
# Epoch 9/10
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7860 - accuracy: 0.5000
# Epoch 10/10
# ...

# %%
print(model.predict([[40.0]]))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# [[0.9727999]]

# %%
import tensorflow as tf
import numpy as np

# Define the input features and labels
xs = np.array([92., 24., 34., 45., 46., 57., 64., 69., 49., 92.])
ys = np.array([1, 0, 0, 0, 0, 1, 1, 1, 0, 1])

# Normalize the input features
#xs_normalized = (xs - np.mean(xs)) / np.std(xs)

# Create a logistic regression model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(1,))
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(xs_normalized, ys, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 300ms/step - loss: 0.3940 - accuracy: 0.9000
# Epoch 2/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.9000
# Epoch 3/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.9000
# Epoch 4/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3934 - accuracy: 0.9000
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3932 - accuracy: 0.9000
# Epoch 6/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3930 - accuracy: 0.9000
# Epoch 7/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.9000
# Epoch 8/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3926 - accuracy: 0.9000
# Epoch 9/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3924 - accuracy: 0.9000
# Epoch 10/10
# ...

# %%
# Predict the output for new inputs
new_inputs = np.array([30., 22., 99.])
#new_inputs_normalized = (new_inputs - np.mean(xs)) / np.std(xs)
predictions = model.predict(new_inputs_normalized)
rounded_predictions = np.round(predictions)

print("Predictions:", rounded_predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [0. 0. 1.]
